# %% [markdown]
# Building an Interactive Dashboard with Ploty Dash

# %%
# !pip install dash
# !pip install dash == 1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (2.14.1)
# Requirement already satisfied: nest-asyncio in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.5.5)
# Requirement already satisfied: plotly>=5.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (5.18.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: ansi2html in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.8.0)
# Requirement already satisfied: Werkzeug<3.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.3)
# Requirement already satisfied: retrying in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.3.4)
# Requirement already satisfied: setuptools in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (63.4.1)
# Requirement already satisfied: importlib-metadata in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (4.11.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (1.1.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (4.3.0)
# Requirement already satisfied: requests in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.28.1)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash) (5.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from Flask<3.1,>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: packaging in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->dash) (3.8.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->dash) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->dash) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->dash) (3.3)
# Requirement already satisfied: six>=1.7.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from packaging->plotly>=5.0.0->dash) (3.0.9)
# zsh:1: = not found
# Requirement already satisfied: jupyter_dash in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (0.4.2)
# Requirement already satisfied: flask in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: retrying in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (1.5.5)
# Requirement already satisfied: requests in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (2.28.1)
# Requirement already satisfied: ansi2html in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (1.8.0)
# Requirement already satisfied: dash in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (2.14.1)
# Requirement already satisfied: ipykernel in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (6.15.2)
# Requirement already satisfied: ipython in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter_dash) (7.31.1)
# Requirement already satisfied: Werkzeug<3.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (2.0.3)
# Requirement already satisfied: importlib-metadata in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (4.11.3)
# Requirement already satisfied: dash-table==5.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (2.0.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (5.18.0)
# Requirement already satisfied: setuptools in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (63.4.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from dash->jupyter_dash) (4.3.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from flask->jupyter_dash) (8.0.4)
# Requirement already satisfied: debugpy>=1.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: psutil in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (5.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (7.3.4)
# Requirement already satisfied: appnope in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: pyzmq>=17 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: packaging in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (21.3)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->jupyter_dash) (5.1.1)
# Requirement already satisfied: backcall in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pygments in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (0.18.1)
# Requirement already satisfied: decorator in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: pickleshare in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter_dash) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter_dash) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from requests->jupyter_dash) (1.26.11)
# Requirement already satisfied: six>=1.7.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from retrying->jupyter_dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (4.11.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: entrypoints in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter_dash) (0.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: wcwidth in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->dash->jupyter_dash) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from packaging->ipykernel->jupyter_dash) (3.0.9)
# Requirement already satisfied: plotly in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (5.18.0)
# Requirement already satisfied: packaging in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from plotly) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/Andrew/opt/anaconda3/lib/python3.9/site-packages (from packaging->plotly) (3.0.9)

# %%
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                       dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True,
                                             style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(id = 'payload-slider',
                                               min = 0,
                                                max = 10000,
                                                step = 1000,
                                                value = [min_payload, max_payload]
                                               ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])
    
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', names='class', title='Success Count for all launch sites')
        return fig
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        filtered_df = filtered_df.groupby(['Launch Site', 'class']).size().reset_index(name='class count')
        fig = px.pie(filtered_df, values='class count', names='class', title=f'Total Success Launches for Site {entered_site}')
        return fig

    
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart', component_property='figure'),
              [Input(component_id='site-dropdown', component_property='value'),
               Input(component_id='payload-slider', component_property='value')])
def scatter(entered_site, payload_range):
    filtered_df = spacex_df[
        (spacex_df['Payload Mass (kg)'] >= payload_range[0]) & (spacex_df['Payload Mass (kg)'] <= payload_range[1])]

    # Check if entered_site is 'ALL'
    if entered_site == 'ALL':
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', color='Booster Version Category',
                         title='Success count on Payload mass for all sites')
        return fig
    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == entered_site]
        fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='class', color='Booster Version Category',
                         title=f'Success count on Payload mass for Site {entered_site}')
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6c/_k2k0y21307_72b2pz8xm4f80000gq/T/ipykernel_33631/3072277715.py in <module>
#       1 # Read the airline data into pandas dataframe
# ----> 2 spacex_df = pd.read_csv("spacex_launch_dash.csv")
#       3 max_payload = spacex_df['Payload Mass (kg)'].max()
#       4 min_payload = spacex_df['Payload Mass (kg)'].min()
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spacex_launch_dash.csv'
